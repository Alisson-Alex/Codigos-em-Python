# %%
import pandas as pd

dados = {
    'Produto':['A', 'B', 'C', 'D', 'E', 'F'],
    'quantidade_vendida':[33, 100, 45, 63, 120, 88]
}

df = pd.DataFrame(dados)
df.plot(x='Produto', y='quantidade_vendida', kind='bar')
# Out:
# <Axes: xlabel='Produto'>

# %%
df.plot(x='Produto', y='quantidade_vendida', kind='pie')
# Out:
# <Axes: ylabel='quantidade_vendida'>

# %%
df.plot(x='Produto', y='quantidade_vendida', kind='line')
# Out:
# <Axes: xlabel='Produto'>
